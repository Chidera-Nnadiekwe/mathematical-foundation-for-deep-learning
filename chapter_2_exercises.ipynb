# %% [markdown]
# # Chapter 2 Exercises
# -----
# ## 1. Hands-on Example
# -----
# ### Setting up the Environment
# - By using **np.random.seed(0)**, I ensure that the random values generated will be the same every time I run the code. This is important for reproducibility.
# - The function **np.random.randn(10, 3)** generates a $[10\times3]$ matrix filled with random numbers sampled from the standard normal distribution ($\mu=0$ and $\sigma=1$). This matrix represents $3$ features, each containing $10$ samples.
# - Printing the matrix helps inspect the input data before using it in further computation or visualization.

# %%
# Import packages
import numpy as np
import matplotlib.pyplot as plt

# Seed for Reproducibility
np.random.seed(0)

# Generate some random input data (10 samples, 3 features)
input_data = np.random.randn(10, 3)
print('Input data:')
print(input_data)
# Out:
# Input data:
# [[ 1.76405235  0.40015721  0.97873798]
#  [ 2.2408932   1.86755799 -0.97727788]
#  [ 0.95008842 -0.15135721 -0.10321885]
#  [ 0.4105985   0.14404357  1.45427351]
#  [ 0.76103773  0.12167502  0.44386323]
#  [ 0.33367433  1.49407907 -0.20515826]
#  [ 0.3130677  -0.85409574 -2.55298982]
#  [ 0.6536186   0.8644362  -0.74216502]
#  [ 2.26975462 -1.45436567  0.04575852]
#  [-0.18718385  1.53277921  1.46935877]]

# %% [markdown]
# ### Define Neural Network Layers
# - The **weight (w) matrix** and the **bias (b) vector** are defined and will be used for a simple transformation of the ```input_data```. This simulates a linear layer of a Neural Network.
# - Using ```np.random.randn(3, 2)```, corresponding to $3$ **features** of the ```input units``` and $2$ ```output units```.
# - The **bias vector** is also initialized randomly with 2 values, representing the biases for the two output units.
# - Printing both the **weights** and **biases**, show the initialized values before deploying them.

# %%
# Define weight matrix (3 features, 2 outputs)
weight = np.random.randn(3, 2)

# Define bias vector
biases = np.random.randn(2)

print('\nWeight:')
print(weight)
print('\nBiases:')
print(biases)
# Out:
# Weight:
# [[ 0.15494743  0.37816252]
#  [-0.88778575 -1.98079647]
#  [-0.34791215  0.15634897]]
#
# Biases:
# [1.23029068 1.20237985]

# %% [markdown]
# ### Perform the Forward Pass
# - Perform a forward pass through a simple linear layer
# - The basic **equation** for the neural network is $$y = wx + b$$ where $y$ = output, $w$ = weight matrix, $x$ = input data/feature, and $b$ = bias vector.
# - The $wx$ is computed by performing **dot product** using ```np.dot()```. This transforms the matrix-vector data into a $2$ output units.
# - The biases ($b$) is added to the dot product.

# %%
# Check the shape of the weight matrix and input_data
print('\nWeight_Shape:', weight.shape)
print('Input_data_Shape:', input_data.shape)
print('Their shapes show that the permissible order of dot product is: "input_data.weight"')

# Perform the forward pass
output_data = np.dot(input_data, weight) + biases
print('\nOutput_data:')
print(output_data)
# Out:
# Weight_Shape: (3, 2)
# Input_data_Shape: (10, 3)
# Their shapes show that the permissible order of dot product is: "input_data.weight"
#
# Output_data:
# [[ 0.80785735  1.22987302]
#  [ 0.25952679 -1.80224699]
#  [ 1.5477883   1.84533734]
#  [ 0.66007261  1.29970598]
#  [ 1.08576476  1.31855991]
#  [ 0.0269476  -1.66297986]
#  [ 2.92526991  2.61340282]
#  [ 0.82234129 -0.378755  ]
#  [ 2.85722849  4.94867267]
#  [-0.67070028 -1.67479699]]

# %% [markdown]
# ### Visualize the Network Transformation
# - Visualize the transformation of the input data into the output data.
# - Matplotlib is used to create two subplots: left (input data) and right (output data)

# %%
# Visualize the input and output data
fig, ax = plt.subplots(1, 2, figsize=(14, 6)) 

# Plot input data
ax[0].scatter(input_data[:, 0], input_data[:, 1], color='blue', s=50, edgecolors='w', label='Input Data')
ax[0].set_title('Input Data')
ax[0].set_xlabel('Feature 1')
ax[0].set_ylabel('Feature 2')
ax[0].legend()
ax[0].grid(True)

# Plot output data
ax[1].scatter(output_data[:, 0], output_data[:, 1], c='red', s=50, edgecolors='w', label='Output Data')
ax[1].set_title('Output Data')
ax[1].set_xlabel('Output 1')
ax[1].set_ylabel('Output 2')
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ----
# ## 2. Programming Questions
# ----
# - ### Easy
# In this exercise, you will generate random input data and apply a transformation using a weight matrix and a bias vector, mimicking the forward pass of a single layer in a neural network.

# %%
# Generate random input data
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0) # Ensure reproducibilty of the random data
input_data_1 = np.random.randn(20, 5) # 20 samples (equations) and 5 input features (variables)
print('\nInput_data_1:')
print(input_data_1)
# Out:
# Input_data_1:
# [[ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799]
#  [-0.97727788  0.95008842 -0.15135721 -0.10321885  0.4105985 ]
#  [ 0.14404357  1.45427351  0.76103773  0.12167502  0.44386323]
#  [ 0.33367433  1.49407907 -0.20515826  0.3130677  -0.85409574]
#  [-2.55298982  0.6536186   0.8644362  -0.74216502  2.26975462]
#  [-1.45436567  0.04575852 -0.18718385  1.53277921  1.46935877]
#  [ 0.15494743  0.37816252 -0.88778575 -1.98079647 -0.34791215]
#  [ 0.15634897  1.23029068  1.20237985 -0.38732682 -0.30230275]
#  [-1.04855297 -1.42001794 -1.70627019  1.9507754  -0.50965218]
#  [-0.4380743  -1.25279536  0.77749036 -1.61389785 -0.21274028]
#  [-0.89546656  0.3869025  -0.51080514 -1.18063218 -0.02818223]
#  [ 0.42833187  0.06651722  0.3024719  -0.63432209 -0.36274117]
#  [-0.67246045 -0.35955316 -0.81314628 -1.7262826   0.17742614]
#  [-0.40178094 -1.63019835  0.46278226 -0.90729836  0.0519454 ]
#  [ 0.72909056  0.12898291  1.13940068 -1.23482582  0.40234164]
# ...

# %%
# Define weights and biases
weights_1 = np.random.randn(5, 4) # 5 input features and 4 output units
biases_1 = np.random.randn(4) # 4 biases added to 4 output units

# Shapes of weights_1 and input_data_1
print('\nWeights_1:', weights_1.shape)
print('Input_data_1:', input_data_1.shape)

print('\nWeigts_1:')
print(weights_1)
print('\nBiases_1:')
print(biases_1)
# Out:
# Weights_1: (5, 4)
# Input_data_1: (20, 5)
#
# Weigts_1:
# [[ 1.8831507  -1.34775906 -1.270485    0.96939671]
#  [-1.17312341  1.94362119 -0.41361898 -0.74745481]
#  [ 1.92294203  1.48051479  1.86755896  0.90604466]
#  [-0.86122569  1.91006495 -0.26800337  0.8024564 ]
#  [ 0.94725197 -0.15501009  0.61407937  0.92220667]]
#
# Biases_1:
# [ 0.37642553 -1.09940079  0.29823817  1.3263859 ]

# %%
# Forward pass with linear transformation
output_data_1 = np.dot(input_data_1, weights_1) + biases_1
print('\nOutput_data_1:')
print(output_data_1)
# Out:
# Output_data_1:
# [[ 4.95015775  2.74063299  0.26563631  7.14462684]
#  [-2.39172312  1.57945809  1.14401502 -0.17244056]
#  [ 0.72073109  2.82335149  1.17495861  1.57552423]
#  [-2.22112782  1.78144361 -1.73520044 -0.18922006]
#  [-0.74655248  3.12219362  6.47852217  0.6438212 ]
#  [-2.70420413  3.37248491  2.26899739  2.29777019]
#  [-0.10622462 -5.61712785 -1.39581317 -1.52079121]
#  [ 1.58689708  2.16827925  1.75440985  1.05817473]
#  [-5.376187   -1.16723029 -1.8045861   0.9207719 ]
#  [ 3.70462967 -4.84252864  3.12688467  1.05129386]
#  [-1.7559109  -2.14750592  0.62103336 -1.26707653]
#  [ 1.8893292  -2.25495841  0.23866887  1.12240569]
#  [-0.37696558 -5.42061111  0.35431176 -1.0151351 ]
#  [ 3.2527328  -4.78227983  2.62230657  1.89453878]
#  [ 5.23368415 -2.56541026  2.02449491  2.34925116]
#  [-0.68319713 -3.32972883  0.56540858  0.59073985]
#  [ 0.75373638 -0.2537933   3.60122015  0.08518488]
#  [ 4.13882275 -3.83854076 -1.99956406  2.23334035]
# ...

# %%
# Data Visualization
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Input Data
ax[0].scatter(input_data_1[:, 1], input_data_1[:, 2], label='Input Data', color='green', s=50, edgecolors='w')
ax[0].set_title('Input Data')
ax[0].set_xlabel('Feature 1')
ax[0].set_ylabel('Feature 2')
ax[0].legend()
ax[0].grid(True)

# Output Data
ax[1].scatter(output_data_1[:, 1], output_data_1[:, 2], label='Output Data', color='blue', s=50, edgecolors='w')
ax[1].set_title('Output Data')
ax[1].set_xlabel('Output Data 1')
ax[1].set_ylabel('Output Data 2')
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# - ### Medium
# In this exercise, you will compare the effects of different weight matrices on the same input data.
#     1. Generate random input data
#     2. Define two different weight matrices
#     3. Forward pass with first weight matrix
#     4. Forward pass with a second weight matrix

# %%
# Random input data
np.random.seed(0)
input_data_2 = np.random.randn(10, 5)
print('\nInput_data_2:')
print(input_data_2)
# Out:
# Input_data_2:
# [[ 1.76405235  0.40015721  0.97873798  2.2408932   1.86755799]
#  [-0.97727788  0.95008842 -0.15135721 -0.10321885  0.4105985 ]
#  [ 0.14404357  1.45427351  0.76103773  0.12167502  0.44386323]
#  [ 0.33367433  1.49407907 -0.20515826  0.3130677  -0.85409574]
#  [-2.55298982  0.6536186   0.8644362  -0.74216502  2.26975462]
#  [-1.45436567  0.04575852 -0.18718385  1.53277921  1.46935877]
#  [ 0.15494743  0.37816252 -0.88778575 -1.98079647 -0.34791215]
#  [ 0.15634897  1.23029068  1.20237985 -0.38732682 -0.30230275]
#  [-1.04855297 -1.42001794 -1.70627019  1.9507754  -0.50965218]
#  [-0.4380743  -1.25279536  0.77749036 -1.61389785 -0.21274028]]

# %%
# Define two different weight matrices and a bias
weights_2a = np.random.randn(5, 3)
weights_2b = np.random.randn(5, 3)
biases_2 = np.random.randn(3)
print('\nWeights_2a:')
print(weights_2a)
print('\nWeights_2b:')
print(weights_2b)
print('\nBiases_2:')
print(biases_2)

# Shapes of wweights_2a, wweights_2b and input_data_2
print('\nWeight_2a:', weights_2a.shape)
print('Weight_2b:', weights_2b.shape)
print('Input_Data_2:', input_data_2.shape)
# Out:
# Weights_2a:
# [[-0.89546656  0.3869025  -0.51080514]
#  [-1.18063218 -0.02818223  0.42833187]
#  [ 0.06651722  0.3024719  -0.63432209]
#  [-0.36274117 -0.67246045 -0.35955316]
#  [-0.81314628 -1.7262826   0.17742614]]
#
# Weights_2b:
# [[-0.40178094 -1.63019835  0.46278226]
#  [-0.90729836  0.0519454   0.72909056]
#  [ 0.12898291  1.13940068 -1.23482582]
#  [ 0.40234164 -0.68481009 -0.87079715]
#  [-0.57884966 -0.31155253  0.05616534]]
#
# Biases_2:
# [-1.16514984  0.90082649  0.46566244]
#
# Weight_2a: (5, 3)
# Weight_2b: (5, 3)
# Input_Data_2: (10, 5)

# %%
# Forward pass with the weight matrices
output_data_2a = np.dot(input_data_2, weights_2a) + biases_2
print('\nOutput Data 2a:')
print(output_data_2a)
print()
output_data_2b = np.dot(input_data_2, weights_2b) + biases_2
print('\nOutput Data 2b:')
print(output_data_2a)
# Out:
# Output Data 2:
# [[-5.48359732 -2.86273875 -1.35922623]
#  [-1.71823792 -0.18924013  1.57778694]
#  [-3.36553831  0.29771015  0.5672572 ]
#  [-2.66060621  2.1896498   0.80121459]
#  [-1.16964481 -3.26304572  2.17093904]
#  [-1.68009468 -3.28704053  1.05648163]
#  [-0.80800407  2.6141903   1.76210859]
#  [-2.29138118  2.07265402  0.23570336]
#  [ 1.04361204 -0.41295639  0.68352154]
#  [ 1.51635422  2.45434231  0.20217794]]
#
#
# Output Data 2:
# [[-5.48359732 -2.86273875 -1.35922623]
#  [-1.71823792 -0.18924013  1.57778694]
#  [-3.36553831  0.29771015  0.5672572 ]
#  [-2.66060621  2.1896498   0.80121459]
#  [-1.16964481 -3.26304572  2.17093904]
#  [-1.68009468 -3.28704053  1.05648163]
#  [-0.80800407  2.6141903   1.76210859]
#  [-2.29138118  2.07265402  0.23570336]
#  [ 1.04361204 -0.41295639  0.68352154]
#  [ 1.51635422  2.45434231  0.20217794]]

# %%
# Data Visualization
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Output Data 2a
ax[0].scatter(output_data_2a[:, 0], output_data_2a[:, 2], label='Output Data 2a', color='red', s=50, edgecolors='w')
ax[0].set_title('Output Data 2a')
ax[0].set_xlabel('Output Data 2a_1')
ax[0].set_ylabel('Output Data 2a_2')
ax[0].legend()
ax[0].grid(True)

# Output Data 2b
ax[1].scatter(output_data_2b[:, 0], output_data_2b[:, 2], label='Output Data 2b', color='black', s=50, edgecolors='w')
ax[1].set_title('Output Data 2b')
ax[1].set_xlabel('Output Data 2b_1')
ax[1].set_ylabel('Output Data 2b_2')
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()
